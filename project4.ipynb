# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("olgabelitskaya/horse-breeds")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 82.0M/82.0M [00:03<00:00, 24.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/olgabelitskaya/horse-breeds/versions/27

# %%
import os

os.listdir(path)
# Out:
# ['02_035.png',
#  '04_026.png',
#  '01_103.png',
#  '06_038.png',
#  '01_046.png',
#  '03_017.png',
#  '01_070.png',
#  '07_049.png',
#  '04_033.png',
#  '02_021.png',
#  '02_062.png',
#  '02_094.png',
#  '01_092.png',
#  '06_065.png',
#  '07_007.png',
#  '03_068.png',
#  '02_048.png',
#  '01_003.png',
#  '01_002.png',
#  '02_027.png',
#  '02_028.png',
#  '06_114.png',
#  '06_088.png',
#  '05_056.png',
#  '07_090.png',
#  '03_038.png',
#  '02_008.png',
#  '04_018.png',
#  '06_096.png',
#  '06_016.png',
#  '03_099.png',
#  '01_083.png',
#  '03_074.png',
#  '06_024.png',
#  '07_073.png',
#  '07_119.png',
#  '07_058.png',
#  '02_056.png',
#  '05_016.png',
#  '02_038.png',
#  '01_033.png',
#  '03_103.png',
#  '02_079.png',
#  '05_040.png',
#  '07_088.png',
#  '05_017.png',
#  '05_050.png',
#  '06_085.png',
#  '02_014.png',
#  '06_112.png',
#  '03_032.png',
#  '06_081.png',
#  '01_069.png',
#  '05_027.png',
#  '06_121.png',
#  '01_063.png',
#  '02_050.png',
#  '01_027.png',
# ...

# %%
import pandas as pd

df = pd.read_csv(os.path.join(path, "horse_breeds.csv"))
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2289165315.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(os.path.join(path, "horse_breeds.csv"))
#       4 df.head()
#
# ...
